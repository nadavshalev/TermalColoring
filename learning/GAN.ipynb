# %%
# example of defining a u-net encoder-decoder generator model
import os
import random
from random import randint
import pandas as pd
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
plt.style.use("grayscale")
# %matplotlib inline
import time

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.losses import mean_absolute_error
import keras.backend as K

from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.models import Model
from keras.models import Input
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.utils.vis_utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
def get_data(path,im_height,im_width):
    ids_x = next(os.walk(path + "TRM"))[2]
    ids_x.sort()
    ids_y = next(os.walk(path + "RGB"))[2]
    ids_y.sort()
    X = np.zeros((len(ids_x), im_height, im_width, 1), dtype=np.float32)
    y = np.zeros((len(ids_y), im_height, im_width, 3), dtype=np.float32)
    
    for n, id_x in tqdm_notebook(enumerate(ids_x), total=len(ids_x)):
        id_y = ids_y[n]
        # Load images
        #img = load_img(path + '/TRM/' + id_x, grayscale=True)
        #x_img = img_to_array(img)
        img = cv.imread(path + '/TRM/' + id_x,cv.COLOR_BGR2GRAY)
        x_img = np.array(img)
        x_img = (x_img - x_img.min()) / (x_img.max() - x_img.min())
        x_img = resize(x_img, (im_height, im_width, 1), mode='constant', preserve_range=True)
        mask = img_to_array(load_img(path + '/RGB/' + id_y, color_mode="rgb"))
        mask = resize(mask, (im_height, im_width, 3), mode='constant', preserve_range=True)
        
        #rgb_image = img_to_array(load_img(path + '/RGB/' + id_y, color_mode="rgb"))
        #lab_image = color.rgb2lab(rgb_image)
        #lab_image = lab_rescale(lab_image, False)
        X[n, ..., 0] = x_img.squeeze()
        y[n] = mask / 255
        
    return X, y

# %% [markdown]
# # Discriminator

# %%
def define_discriminator(t_image_shape, c_image_shape):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# source image input
	in_src_image = Input(shape=t_image_shape)
	# target image input
	in_target_image = Input(shape=c_image_shape)
	# concatenate images channel-wise
	merged = Concatenate()([in_src_image, in_target_image])
	# C64
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
	d = LeakyReLU(alpha=0.2)(d)
	# C128
	d = Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256
	d = Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C512
	d = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	d = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	patch_out = Activation('sigmoid')(d)
	# define model
	model = Model([in_src_image, in_target_image], patch_out)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
	return model

# %% [markdown]
# # Generator blocks

# %%
# Encoder block
def define_encoder_block(layer_in, n_filters, batchnorm=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add downsampling layer
	g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# conditionally add batch normalization
	if batchnorm:
		g = BatchNormalization()(g, training=True)
	# leaky relu activation
	g = LeakyReLU(alpha=0.2)(g)
	return g
 
# Decoder block
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add upsampling layer
	g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# add batch normalization
	g = BatchNormalization()(g, training=True)
	# conditionally add dropout
	if dropout:
		g = Dropout(0.5)(g, training=True)
	# merge with skip connection
	g = Concatenate()([g, skip_in])
	# relu activation
	g = Activation('relu')(g)
	return g

# %% [markdown]
# # Generator model

# %%
def define_generator(image_shape=(256,256,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# image input
	in_image = Input(shape=image_shape)
	# encoder model: C64-C128-C256-C512-C512-C512-C512-C512
	e1 = define_encoder_block(in_image, 64, batchnorm=False)
	e2 = define_encoder_block(e1, 128)
	e3 = define_encoder_block(e2, 256)
	e4 = define_encoder_block(e3, 512)
	e5 = define_encoder_block(e4, 512)
	e6 = define_encoder_block(e5, 512)
	e7 = define_encoder_block(e6, 512)
	# bottleneck, no batch norm and relu
	b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
	b = Activation('relu')(b)
	# decoder model: CD512-CD1024-CD1024-C1024-C1024-C512-C256-C128
	d1 = decoder_block(b, e7, 512)
	d2 = decoder_block(d1, e6, 512)
	d3 = decoder_block(d2, e5, 512)
	d4 = decoder_block(d3, e4, 512, dropout=False)
	d5 = decoder_block(d4, e3, 256, dropout=False)
	d6 = decoder_block(d5, e2, 128, dropout=False)
	d7 = decoder_block(d6, e1, 64, dropout=False)
	# output
	g = Conv2DTranspose(3, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7)
	out_image = Activation('tanh')(g)
	# define model
	model = Model(in_image, out_image)
	return model

# %% [markdown]
# # GAN model

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model, image_shape):
	# make weights in the discriminator not trainable
	d_model.trainable = False
	# define the source image
	in_src = Input(shape=image_shape)
	# connect the source image to the generator input
	gen_out = g_model(in_src)
	# connect the source input and generator output to the discriminator input
	dis_out = d_model([in_src, gen_out])
	# src image as input, generated image and classification output
	model = Model(in_src, [dis_out, gen_out])
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss=['binary_crossentropy', 'mae'], optimizer=opt, loss_weights=[1,100])
	return model

# %%
def generate_real_samples(X,Y, n_samples, patch_shape):
    # choose random instances
    ix = randint(0, X.shape[0]-1)
    # retrieve selected images
    x, y = X[ix], Y[ix]
    if len(x.shape) != 4:
        x = np.expand_dims(x, axis=0)
        y = np.expand_dims(y, axis=0)
    z = np.ones((n_samples, patch_shape, patch_shape, 1))
    return [x, y], z

def generate_fake_samples(g_model, samples, patch_shape):
	# generate fake instance
	X = g_model.predict(samples)
	# create 'fake' class labels (0)
	z = np.zeros((len(X), patch_shape, patch_shape, 1))
	return X, z

# %%
# train pix2pix models
def train(d_model, g_model, gan_model, X, Y, n_steps):
    n_batch=1; n_patch=16
    g_l1_min = 100
    g_cross_min = 100
    d1 = []; d2 = []; g1 = []; g2 = []; g3 = [];
    # manually enumerate epochs
    for i in range(n_steps):
        start_time = time.time()
        # select a batch of real samples
        [X_realA, X_realB], y_real = generate_real_samples(X, Y, n_batch, n_patch)
        # generate a batch of fake samples
        X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
        # update discriminator for real samples
        d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
        # update discriminator for generated samples
        d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
        # update the generator
        g_total, g_cross, g_l1 = gan_model.train_on_batch(X_realA, [y_real, X_realB])
        print('>%d, d_real[%.3f] d_fake[%.3f] g_total[%.3f] g_cross[%.3f] g_l1[%.3f] %.3f[sec]' % (i, d_loss1, d_loss2, g_total, g_cross, g_l1, time.time()-start_time))
        # summarize performance
        d1.append(d_loss1);d2.append(d_loss2);g1.append(g_total);g2.append(g_cross);g3.append(g_l1);
        if i % 20 == 0:
            g_model.save_weights('g_model_nocrop_l1-salt.h5')
            d_model.save_weights('d_model_nocrop_l1-salt.h5')
            if g_l1 < g_l1_min:
                g_model.save_weights('g_model_l1_best-salt.h5')
            if g_cross < g_cross_min:
                g_model.save_weights('g_model_cross_best-salt.h5')
    
    return d1, d2, g1, g2, g3

# %%
def plot_sample(X, Y, g_model, i):
    x = np.expand_dims(X[i], axis=0)
    y = np.expand_dims(Y[i], axis=0)
    xi = g_model.predict(x)
    yim = y
    
    fig, ax = plt.subplots(1, 3, figsize=(20, 10))
    ax[0].imshow(x.squeeze())
    ax[0].set_title('IT')

    ax[1].imshow(yim.squeeze())
    ax[1].set_title('Color')

    ax[2].imshow(xi.squeeze())
    ax[2].set_title('Pred')
    return xi

# %%
im_width = 256; im_height = 256
border = 5
path_train = '../../../data/FLIR/training/Calib/'
X,Y = get_data(path_train,im_height,im_width)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1014/1064,random_state=2019)
# Out:
# HBox(children=(IntProgress(value=0, max=1064), HTML(value='')))

# %%
# define image shape
t_image_shape = (256,256,1);c_image_shape = (256,256,3)
# define the models
d_model = define_discriminator(t_image_shape, c_image_shape)
g_model = define_generator(t_image_shape)
#g_model.load_weights('g_model_nocrop_l1-salt.h5')
#d_model.load_weights('d_model_nocrop_l1-salt.h5')
# define the composite model
gan_model = define_gan(g_model, d_model, t_image_shape)
# summarize the model
# gan_model.summary()
# plot the model
# plot_model(gan_model, to_file='gan_model_plot.png', show_shapes=True, show_layer_names=True)

# %%
d1, d2, g1, g2, g3 = train(d_model, g_model, gan_model, X_train,y_train, n_steps=200)
# Out:
# >0, d_real[0.037] d_fake[0.087] g_total[28.871] g_cross[2.744] g_l1[0.261] 0.786[sec]
# >1, d_real[0.090] d_fake[0.058] g_total[27.772] g_cross[2.803] g_l1[0.250] 0.705[sec]
# >2, d_real[0.117] d_fake[0.046] g_total[19.149] g_cross[2.703] g_l1[0.164] 0.725[sec]
# >3, d_real[0.026] d_fake[0.044] g_total[17.085] g_cross[2.797] g_l1[0.143] 0.727[sec]
# >4, d_real[0.012] d_fake[0.041] g_total[18.610] g_cross[2.890] g_l1[0.157] 0.730[sec]
# >5, d_real[0.017] d_fake[0.033] g_total[25.982] g_cross[3.099] g_l1[0.229] 0.727[sec]
# >6, d_real[0.006] d_fake[0.065] g_total[17.916] g_cross[2.629] g_l1[0.153] 0.726[sec]
# >7, d_real[0.009] d_fake[0.026] g_total[23.366] g_cross[3.369] g_l1[0.200] 0.721[sec]
# >8, d_real[0.016] d_fake[0.025] g_total[22.493] g_cross[3.451] g_l1[0.190] 0.725[sec]
# >9, d_real[0.007] d_fake[0.023] g_total[24.202] g_cross[3.476] g_l1[0.207] 0.727[sec]
# >10, d_real[0.008] d_fake[0.023] g_total[26.396] g_cross[3.447] g_l1[0.229] 0.725[sec]
# >11, d_real[0.007] d_fake[0.019] g_total[23.475] g_cross[3.655] g_l1[0.198] 0.729[sec]
# >12, d_real[0.006] d_fake[0.025] g_total[26.601] g_cross[3.534] g_l1[0.231] 0.726[sec]
# >13, d_real[0.008] d_fake[0.016] g_total[24.601] g_cross[3.795] g_l1[0.208] 0.722[sec]
# >14, d_real[0.009] d_fake[0.052] g_total[23.947] g_cross[3.488] g_l1[0.205] 0.727[sec]
# >15, d_real[0.038] d_fake[0.015] g_total[20.782] g_cross[3.932] g_l1[0.168] 0.727[sec]
# >16, d_real[0.010] d_fake[0.039] g_total[23.645] g_cross[3.515] g_l1[0.201] 0.725[sec]
# >17, d_real[0.298] d_fake[0.036] g_total[29.331] g_cross[2.942] g_l1[0.264] 0.727[sec]
# >18, d_real[0.029] d_fake[0.293] g_total[22.455] g_cross[3.399] g_l1[0.191] 0.725[sec]
# >19, d_real[0.257] d_fake[0.064] g_total[18.906] g_cross[2.709] g_l1[0.162] 0.728[sec]
# >20, d_real[0.079] d_fake[0.243] g_total[18.865] g_cross[3.274] g_l1[0.156] 0.724[sec]
# >21, d_real[0.017] d_fake[0.032] g_total[22.411] g_cross[3.857] g_l1[0.186] 0.701[sec]
# >22, d_real[0.202] d_fake[0.086] g_total[16.582] g_cross[2.131] g_l1[0.145] 0.776[sec]
# >23, d_real[0.012] d_fake[0.411] g_total[18.290] g_cross[3.925] g_l1[0.144] 0.777[sec]
# >24, d_real[0.053] d_fake[0.010] g_total[21.550] g_cross[4.381] g_l1[0.172] 0.780[sec]
# >25, d_real[0.038] d_fake[0.018] g_total[16.644] g_cross[3.838] g_l1[0.128] 0.778[sec]
# >26, d_real[0.066] d_fake[0.018] g_total[20.473] g_cross[3.480] g_l1[0.170] 0.781[sec]
# >27, d_real[0.010] d_fake[0.032] g_total[20.520] g_cross[3.465] g_l1[0.171] 0.784[sec]
# >28, d_real[0.005] d_fake[0.227] g_total[16.617] g_cross[4.003] g_l1[0.126] 0.779[sec]
# >29, d_real[0.030] d_fake[0.011] g_total[19.854] g_cross[4.319] g_l1[0.155] 0.777[sec]
# >30, d_real[0.661] d_fake[1.059] g_total[22.516] g_cross[1.760] g_l1[0.208] 0.781[sec]
# >31, d_real[0.039] d_fake[0.161] g_total[21.953] g_cross[2.378] g_l1[0.196] 0.774[sec]
# >32, d_real[0.039] d_fake[0.202] g_total[16.209] g_cross[2.057] g_l1[0.142] 0.779[sec]
# >33, d_real[0.277] d_fake[0.240] g_total[18.398] g_cross[2.263] g_l1[0.161] 0.779[sec]
# >34, d_real[0.123] d_fake[0.312] g_total[19.821] g_cross[3.149] g_l1[0.167] 0.777[sec]
# >35, d_real[0.991] d_fake[0.626] g_total[18.025] g_cross[2.038] g_l1[0.160] 0.780[sec]
# >36, d_real[0.200] d_fake[0.210] g_total[12.686] g_cross[2.423] g_l1[0.103] 0.777[sec]
# >37, d_real[0.829] d_fake[0.226] g_total[15.594] g_cross[1.485] g_l1[0.141] 0.783[sec]
# >38, d_real[0.043] d_fake[0.194] g_total[21.401] g_cross[2.170] g_l1[0.192] 0.780[sec]
# >39, d_real[0.534] d_fake[0.263] g_total[14.117] g_cross[1.802] g_l1[0.123] 0.780[sec]
# >40, d_real[0.113] d_fake[0.183] g_total[18.344] g_cross[2.158] g_l1[0.162] 0.781[sec]
# >41, d_real[0.327] d_fake[0.510] g_total[11.227] g_cross[2.388] g_l1[0.088] 0.699[sec]
# >42, d_real[0.333] d_fake[0.180] g_total[12.562] g_cross[2.061] g_l1[0.105] 0.780[sec]
# >43, d_real[0.254] d_fake[0.421] g_total[13.668] g_cross[2.941] g_l1[0.107] 0.781[sec]
# >44, d_real[0.243] d_fake[0.082] g_total[21.376] g_cross[2.465] g_l1[0.189] 0.772[sec]
# >45, d_real[0.097] d_fake[0.323] g_total[12.870] g_cross[3.350] g_l1[0.095] 0.777[sec]
# >46, d_real[0.487] d_fake[0.112] g_total[27.150] g_cross[2.984] g_l1[0.242] 0.774[sec]
# >47, d_real[1.049] d_fake[0.390] g_total[8.946] g_cross[1.372] g_l1[0.076] 0.771[sec]
# >48, d_real[0.217] d_fake[0.320] g_total[20.543] g_cross[1.565] g_l1[0.190] 0.772[sec]
# >49, d_real[0.068] d_fake[0.421] g_total[14.554] g_cross[1.927] g_l1[0.126] 1.000[sec]
# >50, d_real[0.708] d_fake[0.276] g_total[15.887] g_cross[1.334] g_l1[0.146] 1.074[sec]
# >51, d_real[0.176] d_fake[0.306] g_total[16.878] g_cross[1.968] g_l1[0.149] 0.807[sec]
# >52, d_real[0.396] d_fake[0.339] g_total[12.587] g_cross[1.737] g_l1[0.108] 0.799[sec]
# >53, d_real[0.284] d_fake[0.270] g_total[16.482] g_cross[1.970] g_l1[0.145] 0.800[sec]
# >54, d_real[0.509] d_fake[0.400] g_total[21.441] g_cross[1.808] g_l1[0.196] 0.799[sec]
# >55, d_real[0.227] d_fake[0.159] g_total[15.029] g_cross[1.807] g_l1[0.132] 0.800[sec]
# >56, d_real[0.092] d_fake[0.138] g_total[14.997] g_cross[2.054] g_l1[0.129] 0.801[sec]
# >57, d_real[0.175] d_fake[0.290] g_total[15.742] g_cross[2.444] g_l1[0.133] 0.791[sec]
# >58, d_real[0.107] d_fake[0.139] g_total[27.646] g_cross[2.701] g_l1[0.249] 0.927[sec]
# >59, d_real[0.370] d_fake[0.758] g_total[12.537] g_cross[3.057] g_l1[0.095] 1.071[sec]
# >60, d_real[0.580] d_fake[0.099] g_total[18.204] g_cross[2.061] g_l1[0.161] 1.070[sec]
# >61, d_real[0.553] d_fake[0.725] g_total[13.932] g_cross[1.947] g_l1[0.120] 0.700[sec]
# >62, d_real[0.242] d_fake[0.144] g_total[16.626] g_cross[1.908] g_l1[0.147] 0.801[sec]
# >63, d_real[0.203] d_fake[0.264] g_total[13.131] g_cross[2.014] g_l1[0.111] 0.796[sec]
# >64, d_real[0.321] d_fake[0.190] g_total[15.206] g_cross[2.009] g_l1[0.132] 0.799[sec]
# >65, d_real[0.320] d_fake[0.334] g_total[16.550] g_cross[1.733] g_l1[0.148] 0.801[sec]
# >66, d_real[0.028] d_fake[0.232] g_total[16.646] g_cross[2.542] g_l1[0.141] 0.800[sec]
# >67, d_real[0.040] d_fake[0.045] g_total[20.372] g_cross[3.004] g_l1[0.174] 0.802[sec]
# >68, d_real[0.434] d_fake[0.678] g_total[15.805] g_cross[2.373] g_l1[0.134] 0.801[sec]
# >69, d_real[0.119] d_fake[0.066] g_total[14.896] g_cross[2.741] g_l1[0.122] 0.801[sec]
# >70, d_real[0.775] d_fake[0.421] g_total[15.663] g_cross[1.879] g_l1[0.138] 0.801[sec]
# >71, d_real[0.331] d_fake[0.185] g_total[18.181] g_cross[1.801] g_l1[0.164] 0.800[sec]
# >72, d_real[0.132] d_fake[0.246] g_total[16.914] g_cross[1.861] g_l1[0.151] 0.799[sec]
# >73, d_real[0.104] d_fake[0.240] g_total[11.451] g_cross[2.407] g_l1[0.090] 0.801[sec]
# >74, d_real[0.752] d_fake[0.215] g_total[14.583] g_cross[1.430] g_l1[0.132] 0.801[sec]
# >75, d_real[0.154] d_fake[0.462] g_total[14.091] g_cross[2.030] g_l1[0.121] 0.802[sec]
# >76, d_real[0.553] d_fake[0.279] g_total[13.860] g_cross[1.427] g_l1[0.124] 0.797[sec]
# >77, d_real[0.170] d_fake[0.327] g_total[12.379] g_cross[2.277] g_l1[0.101] 0.798[sec]
# >78, d_real[0.347] d_fake[0.138] g_total[11.096] g_cross[1.854] g_l1[0.092] 0.798[sec]
# >79, d_real[0.106] d_fake[0.265] g_total[12.550] g_cross[2.425] g_l1[0.101] 0.805[sec]
# >80, d_real[0.058] d_fake[0.074] g_total[14.018] g_cross[2.544] g_l1[0.115] 0.812[sec]
# >81, d_real[0.024] d_fake[0.114] g_total[13.694] g_cross[2.806] g_l1[0.109] 0.701[sec]
# >82, d_real[0.221] d_fake[0.125] g_total[13.389] g_cross[2.394] g_l1[0.110] 0.787[sec]
# >83, d_real[0.024] d_fake[0.743] g_total[15.366] g_cross[3.790] g_l1[0.116] 0.807[sec]
# >84, d_real[1.337] d_fake[0.038] g_total[21.932] g_cross[2.515] g_l1[0.194] 0.796[sec]
# >85, d_real[0.616] d_fake[0.203] g_total[13.971] g_cross[1.416] g_l1[0.126] 0.791[sec]
# >86, d_real[0.369] d_fake[0.619] g_total[8.674] g_cross[1.030] g_l1[0.076] 0.797[sec]
# >87, d_real[0.542] d_fake[0.324] g_total[15.749] g_cross[1.202] g_l1[0.145] 0.803[sec]
# >88, d_real[0.600] d_fake[0.286] g_total[8.915] g_cross[1.101] g_l1[0.078] 0.802[sec]
# >89, d_real[0.374] d_fake[0.387] g_total[12.607] g_cross[1.209] g_l1[0.114] 0.962[sec]
# >90, d_real[0.309] d_fake[0.334] g_total[15.350] g_cross[1.190] g_l1[0.142] 1.079[sec]
# >91, d_real[0.154] d_fake[0.317] g_total[13.234] g_cross[1.342] g_l1[0.119] 0.820[sec]
# >92, d_real[0.303] d_fake[0.218] g_total[17.149] g_cross[1.510] g_l1[0.156] 0.798[sec]
# >93, d_real[0.190] d_fake[0.337] g_total[15.688] g_cross[1.748] g_l1[0.139] 0.795[sec]
# >94, d_real[0.171] d_fake[0.122] g_total[13.750] g_cross[1.860] g_l1[0.119] 0.790[sec]
# >95, d_real[0.466] d_fake[0.202] g_total[16.948] g_cross[1.348] g_l1[0.156] 0.799[sec]
# >96, d_real[0.133] d_fake[0.284] g_total[11.653] g_cross[1.562] g_l1[0.101] 0.801[sec]
# >97, d_real[0.159] d_fake[0.264] g_total[9.839] g_cross[1.730] g_l1[0.081] 0.800[sec]
# >98, d_real[0.902] d_fake[0.272] g_total[10.344] g_cross[1.076] g_l1[0.093] 0.798[sec]
# >99, d_real[0.138] d_fake[0.560] g_total[11.502] g_cross[1.355] g_l1[0.101] 0.793[sec]
# >100, d_real[0.353] d_fake[0.313] g_total[11.801] g_cross[1.285] g_l1[0.105] 0.801[sec]
# >101, d_real[0.473] d_fake[0.244] g_total[19.303] g_cross[1.362] g_l1[0.179] 0.698[sec]
# >102, d_real[0.272] d_fake[0.396] g_total[9.860] g_cross[1.094] g_l1[0.088] 0.791[sec]
# >103, d_real[0.323] d_fake[0.373] g_total[14.187] g_cross[1.162] g_l1[0.130] 0.797[sec]
# >104, d_real[0.305] d_fake[0.314] g_total[8.315] g_cross[1.300] g_l1[0.070] 0.800[sec]
# >105, d_real[0.396] d_fake[0.249] g_total[12.794] g_cross[1.355] g_l1[0.114] 0.799[sec]
# >106, d_real[0.210] d_fake[0.375] g_total[12.843] g_cross[1.368] g_l1[0.115] 0.803[sec]
# >107, d_real[0.271] d_fake[0.202] g_total[15.698] g_cross[1.544] g_l1[0.142] 0.799[sec]
# >108, d_real[0.320] d_fake[0.361] g_total[13.925] g_cross[1.745] g_l1[0.122] 0.798[sec]
# >109, d_real[0.427] d_fake[0.225] g_total[10.387] g_cross[1.349] g_l1[0.090] 0.802[sec]
# >110, d_real[0.251] d_fake[0.452] g_total[11.648] g_cross[1.758] g_l1[0.099] 0.801[sec]
# >111, d_real[0.203] d_fake[0.146] g_total[14.029] g_cross[1.873] g_l1[0.122] 0.798[sec]
# >112, d_real[0.259] d_fake[0.191] g_total[9.614] g_cross[1.587] g_l1[0.080] 0.801[sec]
# >113, d_real[0.038] d_fake[0.226] g_total[11.365] g_cross[2.267] g_l1[0.091] 0.797[sec]
# >114, d_real[0.198] d_fake[0.067] g_total[22.355] g_cross[2.325] g_l1[0.200] 0.801[sec]
# >115, d_real[0.394] d_fake[0.195] g_total[11.835] g_cross[1.381] g_l1[0.105] 0.803[sec]
# >116, d_real[0.038] d_fake[0.244] g_total[10.899] g_cross[2.141] g_l1[0.088] 0.800[sec]
# >117, d_real[0.393] d_fake[0.309] g_total[10.583] g_cross[1.974] g_l1[0.086] 0.799[sec]
# >118, d_real[0.155] d_fake[0.160] g_total[12.411] g_cross[2.079] g_l1[0.103] 0.790[sec]
# >119, d_real[0.140] d_fake[0.141] g_total[12.299] g_cross[2.298] g_l1[0.100] 0.799[sec]
# >120, d_real[0.294] d_fake[0.822] g_total[11.622] g_cross[2.908] g_l1[0.087] 0.790[sec]
# >121, d_real[0.877] d_fake[0.106] g_total[10.613] g_cross[1.689] g_l1[0.089] 0.710[sec]
# >122, d_real[0.464] d_fake[0.429] g_total[9.535] g_cross[1.113] g_l1[0.084] 0.798[sec]
# >123, d_real[0.205] d_fake[0.302] g_total[11.116] g_cross[1.452] g_l1[0.097] 0.798[sec]
# >124, d_real[0.249] d_fake[0.274] g_total[8.026] g_cross[1.430] g_l1[0.066] 0.798[sec]
# >125, d_real[0.197] d_fake[0.269] g_total[9.301] g_cross[1.590] g_l1[0.077] 0.799[sec]
# >126, d_real[0.471] d_fake[0.236] g_total[10.923] g_cross[1.362] g_l1[0.096] 0.798[sec]
# >127, d_real[0.188] d_fake[0.420] g_total[16.960] g_cross[1.739] g_l1[0.152] 0.800[sec]
# >128, d_real[0.131] d_fake[0.410] g_total[12.628] g_cross[2.329] g_l1[0.103] 0.802[sec]
# >129, d_real[0.555] d_fake[0.090] g_total[30.724] g_cross[2.119] g_l1[0.286] 0.800[sec]
# >130, d_real[0.544] d_fake[0.243] g_total[17.781] g_cross[1.497] g_l1[0.163] 0.799[sec]
# >131, d_real[0.654] d_fake[0.427] g_total[15.506] g_cross[1.010] g_l1[0.145] 0.798[sec]
# >132, d_real[0.305] d_fake[0.336] g_total[12.989] g_cross[1.166] g_l1[0.118] 0.789[sec]
# >133, d_real[0.208] d_fake[0.322] g_total[15.448] g_cross[1.314] g_l1[0.141] 0.800[sec]
# >134, d_real[0.211] d_fake[0.178] g_total[15.093] g_cross[1.578] g_l1[0.135] 0.795[sec]
# >135, d_real[0.247] d_fake[0.287] g_total[11.270] g_cross[1.395] g_l1[0.099] 0.798[sec]
# >136, d_real[0.117] d_fake[0.161] g_total[12.164] g_cross[1.774] g_l1[0.104] 0.787[sec]
# >137, d_real[0.194] d_fake[0.242] g_total[9.209] g_cross[1.794] g_l1[0.074] 0.801[sec]
# >138, d_real[0.216] d_fake[0.126] g_total[8.935] g_cross[1.936] g_l1[0.070] 0.798[sec]
# >139, d_real[0.142] d_fake[0.230] g_total[19.041] g_cross[2.204] g_l1[0.168] 0.797[sec]
# >140, d_real[0.193] d_fake[0.170] g_total[11.093] g_cross[1.992] g_l1[0.091] 0.793[sec]
# >141, d_real[0.225] d_fake[0.173] g_total[16.880] g_cross[1.993] g_l1[0.149] 0.698[sec]
# >142, d_real[0.049] d_fake[0.474] g_total[19.921] g_cross[2.903] g_l1[0.170] 0.795[sec]
# >143, d_real[0.491] d_fake[0.337] g_total[11.557] g_cross[2.355] g_l1[0.092] 0.801[sec]
# >144, d_real[0.324] d_fake[0.152] g_total[14.187] g_cross[2.079] g_l1[0.121] 0.800[sec]
# >145, d_real[0.302] d_fake[0.353] g_total[9.335] g_cross[1.923] g_l1[0.074] 0.798[sec]
# >146, d_real[0.237] d_fake[0.145] g_total[11.524] g_cross[1.934] g_l1[0.096] 0.800[sec]
# >147, d_real[0.196] d_fake[0.298] g_total[14.001] g_cross[2.148] g_l1[0.119] 0.800[sec]
# >148, d_real[0.225] d_fake[0.276] g_total[9.156] g_cross[2.088] g_l1[0.071] 0.800[sec]
# >149, d_real[0.175] d_fake[0.096] g_total[13.213] g_cross[2.209] g_l1[0.110] 0.797[sec]
# >150, d_real[0.403] d_fake[0.672] g_total[11.358] g_cross[2.047] g_l1[0.093] 0.789[sec]
# >151, d_real[0.213] d_fake[0.226] g_total[11.846] g_cross[2.033] g_l1[0.098] 0.803[sec]
# >152, d_real[0.318] d_fake[0.187] g_total[9.225] g_cross[1.914] g_l1[0.073] 0.799[sec]
# >153, d_real[0.139] d_fake[0.218] g_total[13.993] g_cross[2.115] g_l1[0.119] 0.798[sec]
# >154, d_real[0.158] d_fake[0.100] g_total[11.571] g_cross[2.088] g_l1[0.095] 0.798[sec]
# >155, d_real[0.143] d_fake[0.157] g_total[9.607] g_cross[2.224] g_l1[0.074] 0.796[sec]
# >156, d_real[0.177] d_fake[0.194] g_total[11.703] g_cross[2.664] g_l1[0.090] 0.786[sec]
# >157, d_real[0.222] d_fake[0.440] g_total[13.120] g_cross[2.306] g_l1[0.108] 0.799[sec]
# >158, d_real[0.569] d_fake[0.246] g_total[9.451] g_cross[1.705] g_l1[0.077] 0.805[sec]
# >159, d_real[0.129] d_fake[0.175] g_total[11.047] g_cross[2.109] g_l1[0.089] 0.799[sec]
# >160, d_real[0.365] d_fake[0.490] g_total[11.010] g_cross[1.899] g_l1[0.091] 0.801[sec]
# >161, d_real[0.263] d_fake[0.270] g_total[15.408] g_cross[2.095] g_l1[0.133] 0.706[sec]
# >162, d_real[0.164] d_fake[0.114] g_total[14.185] g_cross[2.240] g_l1[0.119] 0.801[sec]
# >163, d_real[0.502] d_fake[0.332] g_total[9.128] g_cross[1.764] g_l1[0.074] 0.802[sec]
# >164, d_real[0.096] d_fake[0.114] g_total[12.372] g_cross[2.161] g_l1[0.102] 0.808[sec]
# >165, d_real[0.077] d_fake[0.209] g_total[14.582] g_cross[2.290] g_l1[0.123] 0.802[sec]
# >166, d_real[0.287] d_fake[0.087] g_total[10.786] g_cross[2.194] g_l1[0.086] 0.798[sec]
# >167, d_real[0.086] d_fake[0.316] g_total[10.419] g_cross[2.571] g_l1[0.078] 0.801[sec]
# >168, d_real[0.105] d_fake[0.053] g_total[14.212] g_cross[2.813] g_l1[0.114] 0.793[sec]
# >169, d_real[0.885] d_fake[0.282] g_total[9.409] g_cross[1.459] g_l1[0.080] 0.801[sec]
# >170, d_real[0.240] d_fake[0.682] g_total[15.390] g_cross[1.708] g_l1[0.137] 0.799[sec]
# >171, d_real[0.125] d_fake[0.110] g_total[17.805] g_cross[2.214] g_l1[0.156] 0.801[sec]
# >172, d_real[0.589] d_fake[0.219] g_total[10.746] g_cross[1.511] g_l1[0.092] 0.800[sec]
# >173, d_real[0.100] d_fake[0.288] g_total[9.357] g_cross[1.996] g_l1[0.074] 0.787[sec]
# >174, d_real[0.096] d_fake[0.099] g_total[30.088] g_cross[2.321] g_l1[0.278] 0.800[sec]
# >175, d_real[0.405] d_fake[0.609] g_total[8.077] g_cross[2.019] g_l1[0.061] 0.794[sec]
# >176, d_real[0.425] d_fake[0.108] g_total[17.708] g_cross[2.067] g_l1[0.156] 0.802[sec]
# >177, d_real[0.146] d_fake[0.168] g_total[15.483] g_cross[2.031] g_l1[0.135] 0.798[sec]
# >178, d_real[0.303] d_fake[0.373] g_total[8.353] g_cross[1.768] g_l1[0.066] 0.799[sec]
# >179, d_real[0.134] d_fake[0.119] g_total[11.435] g_cross[2.118] g_l1[0.093] 0.801[sec]
# >180, d_real[0.143] d_fake[0.134] g_total[13.995] g_cross[2.052] g_l1[0.119] 0.802[sec]
# >181, d_real[0.285] d_fake[0.504] g_total[15.004] g_cross[2.426] g_l1[0.126] 0.705[sec]
# >182, d_real[0.121] d_fake[0.057] g_total[14.057] g_cross[2.612] g_l1[0.114] 0.798[sec]
# >183, d_real[0.609] d_fake[0.672] g_total[14.388] g_cross[1.807] g_l1[0.126] 0.790[sec]
# >184, d_real[0.172] d_fake[0.135] g_total[11.929] g_cross[1.952] g_l1[0.100] 0.801[sec]
# >185, d_real[0.147] d_fake[0.153] g_total[10.622] g_cross[2.223] g_l1[0.084] 0.798[sec]
# >186, d_real[0.268] d_fake[0.318] g_total[11.952] g_cross[1.751] g_l1[0.102] 0.800[sec]
# >187, d_real[0.113] d_fake[0.077] g_total[12.733] g_cross[2.475] g_l1[0.103] 0.802[sec]
# >188, d_real[0.359] d_fake[0.353] g_total[9.814] g_cross[1.787] g_l1[0.080] 0.800[sec]
# >189, d_real[0.354] d_fake[0.334] g_total[12.217] g_cross[2.139] g_l1[0.101] 0.798[sec]
# >190, d_real[0.114] d_fake[0.151] g_total[17.650] g_cross[2.363] g_l1[0.153] 0.799[sec]
# >191, d_real[0.190] d_fake[0.131] g_total[12.180] g_cross[2.403] g_l1[0.098] 0.799[sec]
# >192, d_real[0.181] d_fake[0.175] g_total[10.983] g_cross[2.256] g_l1[0.087] 0.803[sec]
# >193, d_real[0.084] d_fake[0.107] g_total[11.705] g_cross[2.570] g_l1[0.091] 0.798[sec]
# >194, d_real[0.157] d_fake[0.238] g_total[9.553] g_cross[2.571] g_l1[0.070] 0.800[sec]
# >195, d_real[0.229] d_fake[0.067] g_total[19.525] g_cross[2.446] g_l1[0.171] 0.799[sec]
# >196, d_real[0.082] d_fake[0.296] g_total[8.081] g_cross[2.661] g_l1[0.054] 0.800[sec]
# >197, d_real[0.415] d_fake[0.235] g_total[14.629] g_cross[2.509] g_l1[0.121] 0.799[sec]
# >198, d_real[0.150] d_fake[0.119] g_total[11.277] g_cross[2.533] g_l1[0.087] 0.799[sec]
# >199, d_real[0.132] d_fake[0.064] g_total[10.814] g_cross[2.524] g_l1[0.083] 0.802[sec]

# %%
i = 4
xi = plot_sample(X_train, y_train, g_model, i)

# %%
g_model.load_weights('g_model_l1_best-salt.h5')
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1014/1064,random_state=2019)

# %%
#plt.plot(g1)
#plt.plot(g2)
plt.plot(g3)
#plt.plot(d1)
#plt.plot(d2)
plt.show()
